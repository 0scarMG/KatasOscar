# %% [markdown]
# ## Kata 3

# %% [markdown]
# Ejercicio 1

# %%
asteroide = 49
if asteroide > 25:
    print("Peligro un asteroide se acerca a la Tierra!!")
else:
    print("No hay peligro")
# Out:
# Peligro un asteroide se acerca a la Tierra!!

# %% [markdown]
# Ejercicio 2

# %%
asteroide = 25
if asteroide > 20:
    print("Mira al cielo hay un asteroide")
elif asteroide == 20:
    print("Mira al cielo hay un asteroide")
else:
    print("No hay asteroide visible")
# Out:
# Mira al cielo hay un asteroide

# %% [markdown]
# Ejercicio 3

# %%
V_asteroide = 26
T_asteroide = 40
if V_asteroide > 25 and T_asteroide > 25:
    print("Peligro un asteroide peligroso viene hacia la tierra")
elif V_asteroide >= 20:
    print("Mira al cielo hay una luz proveniente de un asteroide")
elif T_asteroide < 25:
    print("No pasa nada")
else:
    print("No pasa nada")
# Out:
# Peligro un asteroide peligroso viene hacia la tierra

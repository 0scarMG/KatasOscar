# %% [markdown]
# ## Kata 4

# %% [markdown]
# Ejercicio 1

# %%
text = """Interesting facts about the Moon. The Moon is Earth's only satellite. There are several interesting facts about the Moon and how it affects life here on Earth. On average, the Moon moves 4cm away from the Earth every year. This yearly drift is not significant enough to cause immediate effects on Earth. The highest daylight temperature of the Moon is 127 C."""
#Partir el Texto
partir_texto = text.split('. ')
partir_texto
# Out:
# ['Interesting facts about the Moon',
#  "The Moon is Earth's only satellite",
#  'There are several interesting facts about the Moon and how it affects life here on Earth',
#  'On average, the Moon moves 4cm away from the Earth every year',
#  'This yearly drift is not significant enough to cause immediate effects on Earth',
#  'The highest daylight temperature of the Moon is 127 C.']

# %%
#Palabras Claves
palabra_claves = ["average", "temperature", "distance"]

# %%
#Ciclo para recorrer la cadena
for sentencia in partir_texto:
    for palabra_claves in palabra_claves:
        if palabra_claves in sentencia:
            print(sentencia)
            break
# Out:
# The Moon is Earth's only satellite
# There are several interesting facts about the Moon and how it affects life here on Earth
# This yearly drift is not significant enough to cause immediate effects on Earth
# The highest daylight temperature of the Moon is 127 C.

# %%
#Ciclo para cambiar C a Celsius
for sentencia in partir_texto:
    for palabra_claves in palabra_claves:
        if palabra_claves in sentencia:
            print(sentencia.replace(' C', ' Celsius'))
            break
# Out:
# Interesting facts about the Moon
# The Moon is Earth's only satellite
# There are several interesting facts about the Moon and how it affects life here on Earth
# This yearly drift is not significant enough to cause immediate effects on Earth
# The highest daylight temperature of the Moon is 127 Celsius.

# %% [markdown]
# Ejercicio 2

# %%
#Datos
planeta = 'Moon'
gravedad = 0.00162
nombre = 'Earth'

# %%
#titulo
titulo = f"""Datos sobre {nombre}"""

# %%
#Plantilla
hechos = f"""{'-'*80}
El nombre del planeta es: {planeta}
La gravedad en {nombre} es: {gravedad * 1000} m/s2"""

# %%
#Union de cadenas
template = f"""{titulo.title()}{hechos}"""
print(template)
# Out:
# Datos Sobre Earth--------------------------------------------------------------------------------
# El nombre del planeta es: Moon
# La gravedad en Earth es: 1.6199999999999999 m/s2

# %%
#Nuevos Datos
planeta = 'Marte'
gravedad = 0.00143
nombre = 'Ganimedes'

# %%
#comprobar la plantilla
print(hechos)
# Out:
# --------------------------------------------------------------------------------
# El nombre del planeta es: Moon
# La gravedad en Earth es: 1.6199999999999999 m/s2

# %%
nuevo_template = """
Datos de Gravedad sobre: {nombre}
-------------------------------------------------------------------------------
Nombre del planeta: {planeta}
Gravedad en {nombre}: {gravedad} m/s2
"""
print(nuevo_template.format(nombre=nombre, planeta=planeta, gravedad=gravedad))
# Out:
# Datos de Gravedad sobre: Ganimedes
# -------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Ganimedes: 0.00143 m/s2

# %%
print(nuevo_template.format(nombre=nombre, planeta=planeta, gravedad=gravedad*1000))
# Out:
# Datos de Gravedad sobre: Ganimedes
# -------------------------------------------------------------------------------
# Nombre del planeta: Marte
# Gravedad en Ganimedes: 1.4300000000000002 m/s2
